# %%
import numpy as np
import matplotlib.pyplot as plt
import allantools 
import pandas as pd 
from datetime import date, timedelta
from astropy.time import Time
from tweezepy import allanvar as tpy

# %%
N = 1000 # Num of points

# Generate noise
sample = np.random.uniform(0, 1, size=(1000,))

sdate = date(2021,1,25)   # start date
edate = date(2023,10,22)   # end date

# Generate dates
dates = pd.date_range(sdate,edate-timedelta(days=1),freq='d').to_julian_date()

# Convert to astropy Time object
t = Time(dates.values, format='jd')

# Besselian year
t_by = t.byear

# Generate random error
# err = np.random.uniform(size=1000)

# %%
np.average(sample)
# Out:
# 0.5155539066137681

# %%
df = pd.DataFrame({'Data':sample,'Besselian':t_by})
df
# Out:
#          Data    Besselian
# 0    0.221371  2021.068120
# 1    0.250238  2021.070858
# 2    0.102465  2021.073596
# 3    0.082736  2021.076334
# 4    0.185806  2021.079072
# ..        ...          ...
# 995  0.002005  2023.792340
# 996  0.510146  2023.795078
# 997  0.332495  2023.797816
# 998  0.582736  2023.800554
# 999  0.521674  2023.803292
#
# [1000 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
plt.title('White Noise')
plt.scatter(df['Besselian'], df['Data'])
plt.xlabel('Year')
plt.ylabel('Freq')
plt.grid()

# %%
def allanoadev(y,t,error):
        
    # === Parameters ===
    
    # Length of observation
    N = len(y)
        
    # m array where 3 < m < N/3 
#     m = np.arange(3,1+round(N//3),1)
    m = np.array([1,10,100])
    # initial sampling time
    tau0 =  np.mean(np.diff(t))
    # steps
    step = tau0
    
    # Empty variance array
    allanvar = []
    # Empty tau values array 
    tau = []
    
    edfs = np.empty(len(m))

    # Iterate over values of m
    for k in range(len(m)): 
        print('Current value of m: ', m[k])
        
        M = N

        outersum = []
        j = 0
        while j < M-2*m[k]+1:
            i = j
            innersum = []
            while i <= j+m[k]-1:
                innersum.append(y[i+m[k]]-y[i])
                i += 1
            outersum.append(0.5*(np.sum(innersum)/m[k])**2)
            j += 1


        # Calculate allan variance
        allanvar.append(np.sum(outersum)/(M-2*m[k]+1))
        
        # Calculate tau
        tau.append(tau0*m[k])
        
        # Calculate edf
        if N // m[k] > 32:
            alpha_int = tpy.noise_id(y,m[k])[0]
#             print(alpha_int)
        if (alpha_int<3) and (alpha_int>-3):
            edfs[k] = tpy.edf_greenhall(alpha_int,2,m[k],N,overlapping=True)
        else:
            edfs[k] = tpy.edf_approx(N,m[k])

    # Calculate allan std dev
    allanstd = np.sqrt(allanvar)
        
    return tau, allanstd, edfs

# %%
tau, allanstd,edfs = allanoadev(df['Data'].values,df['Besselian'].values,None)
# Out:
# Current value of m:  1
# Current value of m:  10
# Current value of m:  100

# %%
allanstd
# Out:
# array([0.29567471, 0.08812091, 0.02661792])

# %%
edfs
# Out:
# array([781.24769043, 134.93442122,  12.8       ])

# %%
def allanoadev(y):
    M = len(y)
    m = np.array([1,10,100])
    allanvar = []
    for k in range(len(m)):
        outersum = []
        j = 0
        while j < M-2*m[k]+1:
            i = j
            innersum = []
            while i <= j+m[k]-1:
                innersum.append(y[i+m[k]]-y[i])
                i += 1
            outersum.append(0.5*(np.sum(innersum)/m[k])**2)
            j += 1
    
        # Calculate allan variance
        allanvar.append(np.sum(outersum)/(M-2*m[k]+1))
        

    return np.sqrt(allanvar)

# %%
allanoadev(df['Data'].values)
# Out:
# array([0.29567471, 0.08812091, 0.02661792])

# %%
def allanmdev(y):
    M = len(y)
    m = np.array([1,10,100])
    allanvar = []
    for k in range(len(m)):
        outersum = []
        j = 0
        while j < M-3*m[k]+2:
            i = j
            middlesum = []
            while i <= j+m[k]-1:
                n = i
                innersum = []
                while n <= i+m[k]-1:
                    innersum.append(y[n+m[k]]-y[n])
                    n += 1
                middlesum.append(np.sum(innersum))
                i += 1
            outersum.append(np.sum(middlesum)**2)
            j += 1 
    
        # Calculate allan variance
        allanvar.append(np.sum(outersum)/((M-3*m[k]+2)*2*m[k]**4))
        

    return np.sqrt(allanvar)

# %%
allanmdev(df['Data'].values)
# Out:
# array([0.29567471, 0.05998476, 0.0175631 ])

# %%
def haddev(y):
    M = len(y)
    m = np.array([1,10,100])
    havar = []
    for k in range(len(m)):
        hsum = []
        i = 0
        while i < M-2:
            hsum.append((y[i+2]-2*y[i+1]+y[i])**2)
            i += 1
    
        # Calculate allan variance
        havar.append(np.sum(hsum)/(6*(M-2)))
        

    return np.sqrt(havar)

# %%
haddev(df['Data'].values)
# Out:
# array([0.29891774, 0.29891774, 0.29891774])

# %%
def ohdev(y):
    M = len(y)
    m = np.array([1,10,100])
    havar = []
    for k in range(len(m)):
        outersum = []
        j = 0
        while j < M-3*m[k]+1:
            i = j
            innersum = []
            while i <= j+m[k]-1:
                innersum.append(y[i+2*m[k]]-2*y[i+m[k]]+y[i])
                i += 1
            outersum.append((np.sum(innersum)/m[k])**2)
            j += 1
    
        # Calculate allan variance
        havar.append(np.sum(outersum)/(6*(M-3*m[k]+1)))

    return np.sqrt(havar)

# %%
ohdev(df['Data'].values)
# Out:
# array([0.29891774, 0.08834513, 0.02637281])
