# %%
import numpy as np
import matplotlib.pyplot as plt
import allantools 
import pandas as pd

# %%
cols = ['R.A. (mas)', 'Dec. (mas)', 'Err.  R.A. (mas)', 'Err. Dec. (mas)', 'Corr.', 'Del.']

# %%
df = pd.read_csv('1803+784_dem.txt', sep='\s+', skiprows=4, names=cols, header=None)
df
# Out:
#                 R.A. (mas)  Dec. (mas)  Err.  R.A. (mas)  Err. Dec. (mas)  \
# 45754.258  -1.909625186745   -1.887001            1.2912           0.7417
# 45759.251  -1.554359283060   -2.305602            1.2032           1.1362
# 45764.244   0.051039534973    1.460398            0.7069           0.6182
# 45769.259  -5.738531827789    0.891000            2.5316           1.1073
# 45864.264  -2.972004238790    0.696600            0.6484           0.6307
# ...                    ...         ...               ...              ...
# 60181.271  -0.607553070938   -0.275702            0.2258           0.2346
# 60188.269   0.015383760990    0.475898            0.1854           0.1910
# 60195.271   0.066453528946    0.082897            0.1307           0.1282
# 60202.270  -1.387176858925   -4.237200            0.1272           0.1330
# 60208.271  -0.030857484537    0.025297            0.1527           0.1679
#
#            Corr.   Del.
# 45754.258 -0.084   40.0
# 45759.251  0.028   19.0
# 45764.244  0.325   21.0
# 45769.259 -0.363   25.0
# 45864.264  0.547   27.0
# ...          ...    ...
# 60181.271  0.037   65.0
# 60188.269  0.278  107.0
# 60195.271  0.102  201.0
# 60202.270  0.139   98.0
# 60208.271  0.070   89.0
#
# [2729 rows x 6 columns]

# %%
df.dtypes
# Out:
# R.A. (mas)           object
# Dec. (mas)          float64
# Err.  R.A. (mas)    float64
# Err. Dec. (mas)     float64
# Corr.               float64
# Del.                float64
# dtype: object

# %%
plt.scatter(df.index, df['Dec. (mas)'],s=1)
plt.ylim(-5,5)
plt.show()

# %%
def allanoadev_opt(y,t,rate):
        
    # === Parameters ===
    
    N = len(y)
    # m array where 3 < m < N/3 
    m = np.arange(3,1+round(N//3),1)
    # Take tau0 as 1/rate
    tau0 = 1/rate
    # steps
    step = 1
    
    # Empty variance array
    allanvar = []
    # Empty tau values array 
    tau = []

    # Iterate over values of m
    for k in range(len(m)): 
        kernels = np.ones(m[k])/m[k]
        ybar = np.convolve(y,kernels,'valid')

        # M is the number of times we can move the averaging window from the beginning to the end
        M = len(ybar)

        # Calculate allan var 
        outersum = []
        for j in np.arange(0,M-2*m[k]+1,step):
            innersum = []
            for i in np.arange(j,j+m[k]-1,step):
                innersum.append(ybar[i+m[k]]-ybar[i])
            outersum.append(0.5*(np.sum(innersum)/m[k])**2)

        # Calculate allan variance
        allanvar.append(np.sum(outersum)/(M-2*m[k]+1))
        
        # Calculate tau
        tau.append(tau0*m[k])

    # Calculate allan std dev
    allanstd = np.sqrt(allanvar)
        
    return tau, allanstd

# %%
t = np.logspace(0, 3, 50) # tau values from 1 to 1000

# %%
# %%time
tau, allanstd = allanoadev_opt(df['Dec. (mas)'],t,1)
# Out:
# CPU times: user 3min 45s, sys: 229 ms, total: 3min 46s
# Wall time: 3min 45s

# %%
plt.loglog(tau,allanstd)
