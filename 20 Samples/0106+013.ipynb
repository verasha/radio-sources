# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import allanself
import scipy

# %%
df = allanself.process_data('data/0019+058_dem.txt')
(df['RAcosDEC']/1000).describe()
# Out:
# count     630.000000
# mean        6.090341
# std       266.665747
# min     -4025.537975
# 25%        -0.376433
# 50%         0.001043
# 75%         0.441643
# max      5074.096720
# Name: RAcosDEC, dtype: float64
