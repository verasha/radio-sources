# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tweezepy import allanvar as tpy
import allanself
import statistics
import scipy

# %% [markdown]
# # Get data

# %%
df = allanself.process_data('ICRF3 Dem/series_ind_dem/1803+784_dem.txt')
df.head(5)
# Out:
#          MJD  R.A. (mas)  Dec. (mas)  Err. R.A. (mas)  Err. Dec. (mas)  Corr.  \
# 0  45754.258   -1.910705   -1.887599           1.2912           0.7417 -0.084
# 1  45759.251   -1.555439   -2.306200           1.2032           1.1362  0.028
# 2  45764.244    0.049960    1.459800           0.7069           0.6182  0.325
# 3  45769.259   -5.739611    0.890402           2.5316           1.1073 -0.363
# 4  45864.264   -2.973084    0.696002           0.6484           0.6307  0.547
#
#    Del.  R.A. (micas)  Dec. (micas)  Err. R.A. (micas)  Err. Dec. (micas)  \
# 0    40  -1910.704737  -1887.598813             1291.2              741.7
# 1    19  -1555.438834  -2306.199571             1203.2             1136.2
# 2    21     49.959984   1459.800012              706.9              618.2
# 3    25  -5739.611378    890.402401             2531.6             1107.3
# 4    27  -2973.083789    696.002411              648.4              630.7
#
#      Dec. (rad)     RAcosDEC           BY
# 0 -9.151337e-09 -1910.704737  1984.147297
# 1 -1.118077e-08 -1555.438834  1984.160968
# 2  7.077310e-09    49.959984  1984.174638
# 3  4.316793e-09 -5739.611378  1984.188369
# 4  3.374315e-09 -2973.083789  1984.448484

# %%
# Choose data under 2015
df_sel = df[df['BY'] < 2015]
len(df_sel)
# Out:
# 2234

# %%
df_sel_dec = allanself.remove_outliers(df_sel,'DEC')
len(df_sel_dec)
# Out:
# 2213

# %%
df_sel_ra = allanself.remove_outliers(df_sel,'RA')
len(df_sel_ra)
# Out:
# 2216

# %% [markdown]
# # Modified Allan
